# %% [markdown]
# # Proyecto Colaborativo\n\nTrabajo de análisis de productos de PCComponentes realizado por Raul, Dani y Andres.\n\nEl proyecto se divide en tres partes principales: scraping, limpieza/análisis y modelado con visualización en Streamlit.

# %%
import pandas as pd\n\ndf = pd.read_csv('notebooks/pccomponentes_productos_limpio.csv')\ndf.head()
