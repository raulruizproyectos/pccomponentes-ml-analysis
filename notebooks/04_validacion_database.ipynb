# %%
password = "Mortymer2025"
port = "5432"
db = "pccomponentes_ml"

DATABASE_URI: str = f"postgresql://postgres:{password}@localhost:{port}/{db}"

print("DATABASE_URI creada correctamente")
# Out:
# DATABASE_URI creada correctamente

# %%
from pathlib import Path
import sys

current_dir = Path.cwd()

if current_dir.name == "notebooks":
    project_root = current_dir.parent
else:
    project_root = current_dir

if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

print(f"Raiz del proyecto: {project_root}")
# Out:
# Raiz del proyecto: c:\Visual Code\PC_COMPONENTES\pccomponentes-ml-analysis

# %%
from database.conexion import conectar_postgresql
import database.consultas as consultas

print("Modulos importados correctamente")
# Out:
# Modulos importados correctamente

# %%
conn = conectar_postgresql(DATABASE_URI)

print("Conexion creada correctamente")
# Out:
# Conexion creada correctamente

# %%
productos = consultas.obtener_productos(conn)

productos
# Out:
# [(1,
#   'MSI GeForce RTX 5070 VENTUS 2X OC 12GB GDDR7 Reflex 2 RTX AI DLSS4',
#   Decimal('579.90')),
#  (2,
#   'Palit GeForce RTX 5060 Infinity 2 OC 8GB GDDR7 Reflex 2 RTX AI DLSS4',
#   Decimal('339.90'))]

# %%
resumen_productos = consultas.obtener_resumen_productos(conn)

resumen_productos
# Out:
# [(1,
#   'MSI GeForce RTX 5070 VENTUS 2X OC 12GB GDDR7 Reflex 2 RTX AI DLSS4',
#   'MSI',
#   Decimal('579.90'),
#   Decimal('4.70'),
#   461,
#   Decimal('93.00'),
#   'NVIDIA GeForce RTX 5070',
#   '12 GB',
#   'GDDR7',
#   '192 bits',
#   409,
#   38,
#   4,
#   2,
#   8),
#  (2,
#   'Palit GeForce RTX 5060 Infinity 2 OC 8GB GDDR7 Reflex 2 RTX AI DLSS4',
#   'Palit',
#   Decimal('339.90'),
#   Decimal('4.40'),
#   46,
#   Decimal('97.00'),
#   'NVIDIA GeForce RTX 5060',
#   '8 GB',
#   'GDDR7',
#   '128 bits',
#   35,
#   5,
#   1,
#   1,
#   4)]

# %%
import pandas as pd

columnas_resumen = [
    "producto_id",
    "modelo",
    "marca",
    "precio",
    "valoracion_media",
    "numero_total_opiniones",
    "porcentaje_recomendacion",
    "gpu",
    "memoria_vram",
    "tipo_memoria",
    "bus_memoria",
    "estrellas_5",
    "estrellas_4",
    "estrellas_3",
    "estrellas_2",
    "estrellas_1"
]

df_resumen_productos = pd.DataFrame(resumen_productos, columns=columnas_resumen)

df_resumen_productos
# Out:
#    producto_id                                             modelo  marca  \
# 0            1  MSI GeForce RTX 5070 VENTUS 2X OC 12GB GDDR7 R...    MSI
# 1            2  Palit GeForce RTX 5060 Infinity 2 OC 8GB GDDR7...  Palit
#
#    precio valoracion_media  numero_total_opiniones porcentaje_recomendacion  \
# 0  579.90             4.70                     461                    93.00
# 1  339.90             4.40                      46                    97.00
#
#                        gpu memoria_vram tipo_memoria bus_memoria  estrellas_5  \
# 0  NVIDIA GeForce RTX 5070        12 GB        GDDR7    192 bits          409
# 1  NVIDIA GeForce RTX 5060         8 GB        GDDR7    128 bits           35
#
#    estrellas_4  estrellas_3  estrellas_2  estrellas_1
# 0           38            4            2            8
# 1            5            1            1            4

# %%
df_resumen_productos["precio"] = df_resumen_productos["precio"].astype(float)
df_resumen_productos["valoracion_media"] = df_resumen_productos["valoracion_media"].astype(float)
df_resumen_productos["porcentaje_recomendacion"] = df_resumen_productos["porcentaje_recomendacion"].astype(float)

df_resumen_productos
# Out:
#    producto_id                                             modelo  marca  \
# 0            1  MSI GeForce RTX 5070 VENTUS 2X OC 12GB GDDR7 R...    MSI
# 1            2  Palit GeForce RTX 5060 Infinity 2 OC 8GB GDDR7...  Palit
#
#    precio  valoracion_media  numero_total_opiniones  porcentaje_recomendacion  \
# 0   579.9               4.7                     461                      93.0
# 1   339.9               4.4                      46                      97.0
#
#                        gpu memoria_vram tipo_memoria bus_memoria  estrellas_5  \
# 0  NVIDIA GeForce RTX 5070        12 GB        GDDR7    192 bits          409
# 1  NVIDIA GeForce RTX 5060         8 GB        GDDR7    128 bits           35
#
#    estrellas_4  estrellas_3  estrellas_2  estrellas_1
# 0           38            4            2            8
# 1            5            1            1            4

# %%
resenas_con_producto = consultas.obtener_resenas_con_producto(conn)

resenas_con_producto
# Out:
# [(1,
#   1,
#   'MSI GeForce RTX 5070 VENTUS 2X OC 12GB GDDR7 Reflex 2 RTX AI DLSS4',
#   'MSI',
#   'seikozertwo',
#   Decimal('5.0'),
#   'La NVIDIA GeForce RTX 5070 es una de las mejores opciones para jugadores exigentes y creadores de contenido.',
#   'Excelente rendimiento en 1440p. Arquitectura nueva generacion. Buen rendimiento en tareas creativas.',
#   'Ninguno hasta la fecha.'),
#  (2,
#   1,
#   'MSI GeForce RTX 5070 VENTUS 2X OC 12GB GDDR7 Reflex 2 RTX AI DLSS4',
#   'MSI',
#   'TLG1983',
#   Decimal('0.5'),
#   'Antes de comprar esta grafica que sepais que su precio relativamente barato es por algo. Es una loteria, este modelo tiene problemas conocidos con el conector de alimentacion. Si tienes suerte es una ganga, sino te toca gestionar la devolucion, como fue mi caso.',
#   'No detectados.',
#   'Problemas conocidos con el conector de alimentacion. Posible devolucion del producto.'),
#  (4,
#   1,
# ...

# %%
with conn.cursor() as cursor:
    cursor.execute("""
        DELETE FROM resenas
        WHERE resena_id IN (%s, %s);
    """, (8, 9))

conn.commit()

print("Reseñas duplicadas eliminadas")
# Out:
# Reseñas duplicadas eliminadas

# %%
resenas_con_producto = consultas.obtener_resenas_con_producto(conn)

resenas_con_producto
# Out:
# [(1,
#   1,
#   'MSI GeForce RTX 5070 VENTUS 2X OC 12GB GDDR7 Reflex 2 RTX AI DLSS4',
#   'MSI',
#   'seikozertwo',
#   Decimal('5.0'),
#   'La NVIDIA GeForce RTX 5070 es una de las mejores opciones para jugadores exigentes y creadores de contenido.',
#   'Excelente rendimiento en 1440p. Arquitectura nueva generacion. Buen rendimiento en tareas creativas.',
#   'Ninguno hasta la fecha.'),
#  (2,
#   1,
#   'MSI GeForce RTX 5070 VENTUS 2X OC 12GB GDDR7 Reflex 2 RTX AI DLSS4',
#   'MSI',
#   'TLG1983',
#   Decimal('0.5'),
#   'Antes de comprar esta grafica que sepais que su precio relativamente barato es por algo. Es una loteria, este modelo tiene problemas conocidos con el conector de alimentacion. Si tienes suerte es una ganga, sino te toca gestionar la devolucion, como fue mi caso.',
#   'No detectados.',
#   'Problemas conocidos con el conector de alimentacion. Posible devolucion del producto.'),
#  (4,
#   1,
# ...

# %%
columnas_resenas = [
    "resena_id",
    "producto_id",
    "modelo",
    "marca",
    "usuario",
    "valoracion",
    "texto_resena",
    "pros",
    "contras"
]

df_resenas = pd.DataFrame(resenas_con_producto, columns=columnas_resenas)

df_resenas["valoracion"] = df_resenas["valoracion"].astype(float)

df_resenas
# Out:
#    resena_id  producto_id                                             modelo  \
# 0          1            1  MSI GeForce RTX 5070 VENTUS 2X OC 12GB GDDR7 R...
# 1          2            1  MSI GeForce RTX 5070 VENTUS 2X OC 12GB GDDR7 R...
# 2          4            1  MSI GeForce RTX 5070 VENTUS 2X OC 12GB GDDR7 R...
# 3          5            2  Palit GeForce RTX 5060 Infinity 2 OC 8GB GDDR7...
# 4          6            2  Palit GeForce RTX 5060 Infinity 2 OC 8GB GDDR7...
# 5          7            2  Palit GeForce RTX 5060 Infinity 2 OC 8GB GDDR7...
#
#    marca      usuario  valoracion  \
# 0    MSI  seikozertwo         5.0
# 1    MSI      TLG1983         0.5
# 2    MSI   sime_kwode         3.5
# 3  Palit      YosuMax         4.0
# 4  Palit       JordiA         2.5
# 5  Palit       __5495         5.0
#
#                                         texto_resena  \
# 0  La NVIDIA GeForce RTX 5070 es una de las mejor...
# 1  Antes de comprar esta grafica que sepais que s...
# ...
